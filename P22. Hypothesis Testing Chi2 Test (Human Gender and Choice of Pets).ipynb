# %% [markdown]
# # Hypothesis Testing Chi2 Test (Human Gender and Choice of Pets)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# %% [raw]
# Assume Null Hypothesis as Ho: Human Gender and choice of pets is independent and not related
# Thus Alternate Hypothesis as Ha : Human Gender and choice of pets is dependent and related

# %%
# Make 3-dimentional Array
obs=np.array([[207,282,241],[234,242,232]])
obs
# Out:
# array([[207, 282, 241],
#        [234, 242, 232]])

# %%
# Chi2 contingency stats
chi2_contingency(obs)  # o/p is (Chi2 stats value, p_value, df, expected obsvations)
# Out:
# (4.542228269825232,
#  0.1031971404730939,
#  2,
#  array([[223.87343533, 266.00834492, 240.11821975],
#         [217.12656467, 257.99165508, 232.88178025]]))

# %%
# comparing p_value with α = 0.05

# %% [raw]
# As (p_valu=0.1031) > (α = 0.05); Accept Null Hypothesis
# i.e Independence among categorical variables
# Thus, there is no relation between Human Gender and Choice of Pets
